# %%
# En tu_notebook.ipynb


print("¡Módulos importados desde 'src' con éxito!")

# Ahora puedes usarlos
# model = QCA_Operator_Deep(D_STATE, HIDDEN_CHANNELS)
# ...
# Out:
# ¡Módulos importados desde 'src' con éxito!
